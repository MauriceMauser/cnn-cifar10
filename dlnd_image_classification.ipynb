# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

# Use Floyd's cifar-10 dataset if present
floyd_cifar10_location = '/input/cifar-10/python.tar.gz'
if isfile(floyd_cifar10_location):
    tar_gz_path = floyd_cifar10_location
else:
    tar_gz_path = 'cifar-10-python.tar.gz'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(tar_gz_path):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            tar_gz_path,
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open(tar_gz_path) as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 5
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 5:
# Image - Min Value: 0 Max Value: 252
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
import numpy as np 

def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # Implement function
    return np.array(x/255)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
import numpy as np
from sklearn import preprocessing
lb = preprocessing.LabelBinarizer()
lb.fit(np.arange(10))

def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # Implement Function
    return lb.transform(np.array(x))


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a bach of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # Implement Function
    tensor_shape = (None,) + image_shape
    return tf.placeholder(tf.float32, shape=tensor_shape, name="x")


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # Implement Function
    tensor_shape = (None, n_classes)
    return tf.placeholder(tf.float32, shape=tensor_shape, name="y")

def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # Implement Function
    return tf.placeholder(tf.float32, name="keep_prob")


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # Implement Function
    # Create Weight and Bias
    x_shape = x_tensor.get_shape().as_list()
    weight = tf.Variable(tf.truncated_normal([conv_ksize[0], conv_ksize[1], x_shape[-1], conv_num_outputs], 
                                             stddev=0.1))
    bias = tf.Variable(tf.zeros(conv_num_outputs))
    
    # Apply Convolution
    x_tensor = tf.nn.conv2d(x_tensor, weight, strides=[1, conv_strides[0], conv_strides[1], 1], 
                            padding='SAME')
    
    # Add Bias
    x_tensor = tf.nn.bias_add(x_tensor, bias)
    
    # Apply ReLU Nonlinearity
    x_tensor = tf.nn.relu(x_tensor)
    
    # Apply Max Pooling
    x_tensor = tf.nn.max_pool(x_tensor, ksize=[1, pool_ksize[0], pool_ksize[1], 1],
                                        strides=[1, pool_strides[0], pool_strides[1], 1],
                              padding='SAME')

    return x_tensor 


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
import numpy as np

def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # Implement Function
    x_shape = x_tensor.get_shape().as_list()
    dim = np.prod(x_shape[1:])
          
    return tf.reshape(x_tensor, [-1, dim])


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # Implement Function
    x_shape = x_tensor.get_shape().as_list()
    weight = tf.Variable(tf.truncated_normal([x_shape[1], num_outputs], stddev=0.1))
    bias = tf.Variable(tf.zeros(num_outputs))
    
    x_tensor = tf.add(tf.matmul(x_tensor, weight), bias)
    x_tensor = tf.sigmoid(x_tensor)
    return x_tensor


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # Implement Function
    x_shape = x_tensor.get_shape().as_list()
    weight = tf.Variable(tf.truncated_normal([x_shape[1], num_outputs], stddev=0.1))
    bias = tf.Variable(tf.zeros(num_outputs))
    
    x_tensor = tf.add(tf.matmul(x_tensor, weight), bias)
    return x_tensor


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    
    # Convolution I: 48 Channels, 4x4 Filter, Stride 1 => ReLu => 2x2 Max Pooling
    # Input: (32x32x3) => Output: (16x16x48)
    
    c1_channels = 48
    c1_conv_ksize = (4,4)
    c1_conv_strides = (1,1)
    c1_pool_ksize = (2,2)
    c1_pool_strides = (2,2)
    
    x = conv2d_maxpool(x, c1_channels, c1_conv_ksize, c1_conv_strides, c1_pool_ksize, c1_pool_strides)
    
    # Convolution II: 128 Channels, 4x4 Filter, Stride 1 => ReLu => 2x2 Max Pooling
    # Input: (16x16x48) => Output: (8x8x128)
    
    c2_channels = 128
    c2_conv_ksize = (4,4)
    c2_conv_strides = (1,1)
    c2_pool_ksize = (2,2)
    c2_pool_strides = (2,2)
    
    x = conv2d_maxpool(x, c2_channels, c2_conv_ksize, c2_conv_strides, c2_pool_ksize, c2_pool_strides)
    

    # Convolution III: 128 Channels, 2x2 Filter, Stride 1 => ReLu => 2x2 Max Pooling
    # Input: (8x8x128) => Output: (4x4x128)
    
    c3_channels = 128
    c3_conv_ksize = (2,2)
    c3_conv_strides = (1,1)
    c3_pool_ksize = (2,2)
    c3_pool_strides = (2,2)
    
    x = conv2d_maxpool(x, c3_channels, c3_conv_ksize, c3_conv_strides, c3_pool_ksize, c3_pool_strides)
    
    # Dropout
    x = tf.nn.dropout(x, keep_prob)
    
    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    x = flatten(x)

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    
    # Fully Connected Layer, with 64 Outputs
    x = fully_conn(x, 64)
    
    # Dropout
    x = tf.nn.dropout(x, keep_prob)
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    x = output(x, 10)
    
    # TODO: return output
    return x


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # Implement Function
    session.run(optimizer, feed_dict={x: feature_batch, y: label_batch, keep_prob: keep_probability})
    pass


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    loss = session.run(cost, feed_dict={x: feature_batch, y: label_batch, keep_prob: 1.0})
    valid_accuracy = session.run(accuracy, feed_dict={x: valid_features, y: valid_labels, keep_prob: 1.0})
        
    print("Loss: {:<8.3} Valid Accuracy: {:<5.3}".format(loss, valid_accuracy))
    pass

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 75
batch_size = 512
keep_probability = 0.5

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Loss: 2.27     Valid Accuracy: 0.152
# Epoch  2, CIFAR-10 Batch 1:  Loss: 2.16     Valid Accuracy: 0.234
# Epoch  3, CIFAR-10 Batch 1:  Loss: 1.99     Valid Accuracy: 0.303
# Epoch  4, CIFAR-10 Batch 1:  Loss: 1.87     Valid Accuracy: 0.35
# Epoch  5, CIFAR-10 Batch 1:  Loss: 1.79     Valid Accuracy: 0.365
# Epoch  6, CIFAR-10 Batch 1:  Loss: 1.74     Valid Accuracy: 0.385
# Epoch  7, CIFAR-10 Batch 1:  Loss: 1.69     Valid Accuracy: 0.415
# Epoch  8, CIFAR-10 Batch 1:  Loss: 1.65     Valid Accuracy: 0.42
# Epoch  9, CIFAR-10 Batch 1:  Loss: 1.59     Valid Accuracy: 0.427
# Epoch 10, CIFAR-10 Batch 1:  Loss: 1.54     Valid Accuracy: 0.451
# Epoch 11, CIFAR-10 Batch 1:  Loss: 1.49     Valid Accuracy: 0.451
# Epoch 12, CIFAR-10 Batch 1:  Loss: 1.45     Valid Accuracy: 0.46
# Epoch 13, CIFAR-10 Batch 1:  Loss: 1.41     Valid Accuracy: 0.475
# Epoch 14, CIFAR-10 Batch 1:  Loss: 1.34     Valid Accuracy: 0.492
# Epoch 15, CIFAR-10 Batch 1:  Loss: 1.31     Valid Accuracy: 0.5
# Epoch 16, CIFAR-10 Batch 1:  Loss: 1.29     Valid Accuracy: 0.496
# Epoch 17, CIFAR-10 Batch 1:  Loss: 1.24     Valid Accuracy: 0.512
# Epoch 18, CIFAR-10 Batch 1:  Loss: 1.21     Valid Accuracy: 0.505
# Epoch 19, CIFAR-10 Batch 1:  Loss: 1.18     Valid Accuracy: 0.511
# Epoch 20, CIFAR-10 Batch 1:  Loss: 1.15     Valid Accuracy: 0.513
# Epoch 21, CIFAR-10 Batch 1:  Loss: 1.1      Valid Accuracy: 0.537
# Epoch 22, CIFAR-10 Batch 1:  Loss: 1.09     Valid Accuracy: 0.527
# Epoch 23, CIFAR-10 Batch 1:  Loss: 1.04     Valid Accuracy: 0.541
# Epoch 24, CIFAR-10 Batch 1:  Loss: 1.03     Valid Accuracy: 0.542
# Epoch 25, CIFAR-10 Batch 1:  Loss: 1.0      Valid Accuracy: 0.547
# Epoch 26, CIFAR-10 Batch 1:  Loss: 0.96     Valid Accuracy: 0.563
# Epoch 27, CIFAR-10 Batch 1:  Loss: 0.94     Valid Accuracy: 0.558
# Epoch 28, CIFAR-10 Batch 1:  Loss: 0.942    Valid Accuracy: 0.561
# Epoch 29, CIFAR-10 Batch 1:  Loss: 0.904    Valid Accuracy: 0.58
# Epoch 30, CIFAR-10 Batch 1:  Loss: 0.874    Valid Accuracy: 0.582
# Epoch 31, CIFAR-10 Batch 1:  Loss: 0.893    Valid Accuracy: 0.569
# Epoch 32, CIFAR-10 Batch 1:  Loss: 0.854    Valid Accuracy: 0.579
# Epoch 33, CIFAR-10 Batch 1:  Loss: 0.812    Valid Accuracy: 0.596
# Epoch 34, CIFAR-10 Batch 1:  Loss: 0.798    Valid Accuracy: 0.59
# Epoch 35, CIFAR-10 Batch 1:  Loss: 0.773    Valid Accuracy: 0.597
# Epoch 36, CIFAR-10 Batch 1:  Loss: 0.758    Valid Accuracy: 0.603
# Epoch 37, CIFAR-10 Batch 1:  Loss: 0.734    Valid Accuracy: 0.609
# Epoch 38, CIFAR-10 Batch 1:  Loss: 0.71     Valid Accuracy: 0.606
# Epoch 39, CIFAR-10 Batch 1:  Loss: 0.694    Valid Accuracy: 0.603
# Epoch 40, CIFAR-10 Batch 1:  Loss: 0.675    Valid Accuracy: 0.611
# Epoch 41, CIFAR-10 Batch 1:  Loss: 0.677    Valid Accuracy: 0.598
# Epoch 42, CIFAR-10 Batch 1:  Loss: 0.664    Valid Accuracy: 0.61
# Epoch 43, CIFAR-10 Batch 1:  Loss: 0.668    Valid Accuracy: 0.604
# Epoch 44, CIFAR-10 Batch 1:  Loss: 0.635    Valid Accuracy: 0.615
# Epoch 45, CIFAR-10 Batch 1:  Loss: 0.613    Valid Accuracy: 0.608
# Epoch 46, CIFAR-10 Batch 1:  Loss: 0.589    Valid Accuracy: 0.621
# Epoch 47, CIFAR-10 Batch 1:  Loss: 0.586    Valid Accuracy: 0.626
# Epoch 48, CIFAR-10 Batch 1:  Loss: 0.564    Valid Accuracy: 0.634
# Epoch 49, CIFAR-10 Batch 1:  Loss: 0.541    Valid Accuracy: 0.64
# Epoch 50, CIFAR-10 Batch 1:  Loss: 0.52     Valid Accuracy: 0.639
# Epoch 51, CIFAR-10 Batch 1:  Loss: 0.516    Valid Accuracy: 0.64
# Epoch 52, CIFAR-10 Batch 1:  Loss: 0.486    Valid Accuracy: 0.644
# Epoch 53, CIFAR-10 Batch 1:  Loss: 0.483    Valid Accuracy: 0.647
# Epoch 54, CIFAR-10 Batch 1:  Loss: 0.497    Valid Accuracy: 0.638
# Epoch 55, CIFAR-10 Batch 1:  Loss: 0.465    Valid Accuracy: 0.653
# Epoch 56, CIFAR-10 Batch 1:  Loss: 0.501    Valid Accuracy: 0.622
# Epoch 57, CIFAR-10 Batch 1:  Loss: 0.437    Valid Accuracy: 0.644
# Epoch 58, CIFAR-10 Batch 1:  Loss: 0.431    Valid Accuracy: 0.653
# Epoch 59, CIFAR-10 Batch 1:  Loss: 0.43     Valid Accuracy: 0.65
# Epoch 60, CIFAR-10 Batch 1:  Loss: 0.423    Valid Accuracy: 0.642
# Epoch 61, CIFAR-10 Batch 1:  Loss: 0.418    Valid Accuracy: 0.644
# Epoch 62, CIFAR-10 Batch 1:  Loss: 0.404    Valid Accuracy: 0.651
# Epoch 63, CIFAR-10 Batch 1:  Loss: 0.377    Valid Accuracy: 0.649
# Epoch 64, CIFAR-10 Batch 1:  Loss: 0.374    Valid Accuracy: 0.649
# Epoch 65, CIFAR-10 Batch 1:  Loss: 0.351    Valid Accuracy: 0.656
# Epoch 66, CIFAR-10 Batch 1:  Loss: 0.361    Valid Accuracy: 0.642
# Epoch 67, CIFAR-10 Batch 1:  Loss: 0.367    Valid Accuracy: 0.649
# Epoch 68, CIFAR-10 Batch 1:  Loss: 0.333    Valid Accuracy: 0.652
# Epoch 69, CIFAR-10 Batch 1:  Loss: 0.338    Valid Accuracy: 0.661
# Epoch 70, CIFAR-10 Batch 1:  Loss: 0.326    Valid Accuracy: 0.655
# Epoch 71, CIFAR-10 Batch 1:  Loss: 0.324    Valid Accuracy: 0.657
# Epoch 72, CIFAR-10 Batch 1:  Loss: 0.293    Valid Accuracy: 0.658
# Epoch 73, CIFAR-10 Batch 1:  Loss: 0.291    Valid Accuracy: 0.657
# Epoch 74, CIFAR-10 Batch 1:  Loss: 0.284    Valid Accuracy: 0.658
# Epoch 75, CIFAR-10 Batch 1:  Loss: 0.307    Valid Accuracy: 0.639

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Loss: 2.25     Valid Accuracy: 0.207
# Epoch  1, CIFAR-10 Batch 2:  Loss: 2.06     Valid Accuracy: 0.288
# Epoch  1, CIFAR-10 Batch 3:  Loss: 1.92     Valid Accuracy: 0.319
# Epoch  1, CIFAR-10 Batch 4:  Loss: 1.83     Valid Accuracy: 0.337
# Epoch  1, CIFAR-10 Batch 5:  Loss: 1.76     Valid Accuracy: 0.375
# Epoch  2, CIFAR-10 Batch 1:  Loss: 1.78     Valid Accuracy: 0.369
# Epoch  2, CIFAR-10 Batch 2:  Loss: 1.68     Valid Accuracy: 0.406
# Epoch  2, CIFAR-10 Batch 3:  Loss: 1.52     Valid Accuracy: 0.426
# Epoch  2, CIFAR-10 Batch 4:  Loss: 1.5      Valid Accuracy: 0.446
# Epoch  2, CIFAR-10 Batch 5:  Loss: 1.52     Valid Accuracy: 0.446
# Epoch  3, CIFAR-10 Batch 1:  Loss: 1.6      Valid Accuracy: 0.447
# Epoch  3, CIFAR-10 Batch 2:  Loss: 1.49     Valid Accuracy: 0.48
# Epoch  3, CIFAR-10 Batch 3:  Loss: 1.33     Valid Accuracy: 0.48
# Epoch  3, CIFAR-10 Batch 4:  Loss: 1.36     Valid Accuracy: 0.488
# Epoch  3, CIFAR-10 Batch 5:  Loss: 1.37     Valid Accuracy: 0.495
# Epoch  4, CIFAR-10 Batch 1:  Loss: 1.41     Valid Accuracy: 0.516
# Epoch  4, CIFAR-10 Batch 2:  Loss: 1.39     Valid Accuracy: 0.505
# Epoch  4, CIFAR-10 Batch 3:  Loss: 1.21     Valid Accuracy: 0.516
# Epoch  4, CIFAR-10 Batch 4:  Loss: 1.21     Valid Accuracy: 0.534
# Epoch  4, CIFAR-10 Batch 5:  Loss: 1.25     Valid Accuracy: 0.535
# Epoch  5, CIFAR-10 Batch 1:  Loss: 1.32     Valid Accuracy: 0.547
# Epoch  5, CIFAR-10 Batch 2:  Loss: 1.31     Valid Accuracy: 0.518
# Epoch  5, CIFAR-10 Batch 3:  Loss: 1.13     Valid Accuracy: 0.55
# Epoch  5, CIFAR-10 Batch 4:  Loss: 1.14     Valid Accuracy: 0.557
# Epoch  5, CIFAR-10 Batch 5:  Loss: 1.18     Valid Accuracy: 0.553
# Epoch  6, CIFAR-10 Batch 1:  Loss: 1.2      Valid Accuracy: 0.569
# Epoch  6, CIFAR-10 Batch 2:  Loss: 1.2      Valid Accuracy: 0.563
# Epoch  6, CIFAR-10 Batch 3:  Loss: 1.06     Valid Accuracy: 0.576
# Epoch  6, CIFAR-10 Batch 4:  Loss: 1.06     Valid Accuracy: 0.573
# Epoch  6, CIFAR-10 Batch 5:  Loss: 1.1      Valid Accuracy: 0.579
# Epoch  7, CIFAR-10 Batch 1:  Loss: 1.16     Valid Accuracy: 0.58
# Epoch  7, CIFAR-10 Batch 2:  Loss: 1.11     Valid Accuracy: 0.594
# Epoch  7, CIFAR-10 Batch 3:  Loss: 1.0      Valid Accuracy: 0.594
# Epoch  7, CIFAR-10 Batch 4:  Loss: 0.988    Valid Accuracy: 0.604
# Epoch  7, CIFAR-10 Batch 5:  Loss: 1.03     Valid Accuracy: 0.609
# Epoch  8, CIFAR-10 Batch 1:  Loss: 1.07     Valid Accuracy: 0.605
# Epoch  8, CIFAR-10 Batch 2:  Loss: 1.02     Valid Accuracy: 0.609
# Epoch  8, CIFAR-10 Batch 3:  Loss: 0.961    Valid Accuracy: 0.602
# Epoch  8, CIFAR-10 Batch 4:  Loss: 0.914    Valid Accuracy: 0.617
# Epoch  8, CIFAR-10 Batch 5:  Loss: 0.961    Valid Accuracy: 0.626
# Epoch  9, CIFAR-10 Batch 1:  Loss: 1.01     Valid Accuracy: 0.622
# Epoch  9, CIFAR-10 Batch 2:  Loss: 0.992    Valid Accuracy: 0.614
# Epoch  9, CIFAR-10 Batch 3:  Loss: 0.897    Valid Accuracy: 0.627
# Epoch  9, CIFAR-10 Batch 4:  Loss: 0.887    Valid Accuracy: 0.624
# Epoch  9, CIFAR-10 Batch 5:  Loss: 0.922    Valid Accuracy: 0.641
# Epoch 10, CIFAR-10 Batch 1:  Loss: 0.988    Valid Accuracy: 0.62
# Epoch 10, CIFAR-10 Batch 2:  Loss: 0.938    Valid Accuracy: 0.64
# Epoch 10, CIFAR-10 Batch 3:  Loss: 0.837    Valid Accuracy: 0.639
# Epoch 10, CIFAR-10 Batch 4:  Loss: 0.835    Valid Accuracy: 0.642
# Epoch 10, CIFAR-10 Batch 5:  Loss: 0.871    Valid Accuracy: 0.652
# Epoch 11, CIFAR-10 Batch 1:  Loss: 0.904    Valid Accuracy: 0.647
# Epoch 11, CIFAR-10 Batch 2:  Loss: 0.886    Valid Accuracy: 0.657
# Epoch 11, CIFAR-10 Batch 3:  Loss: 0.808    Valid Accuracy: 0.649
# Epoch 11, CIFAR-10 Batch 4:  Loss: 0.797    Valid Accuracy: 0.656
# Epoch 11, CIFAR-10 Batch 5:  Loss: 0.838    Valid Accuracy: 0.663
# Epoch 12, CIFAR-10 Batch 1:  Loss: 0.867    Valid Accuracy: 0.656
# Epoch 12, CIFAR-10 Batch 2:  Loss: 0.87     Valid Accuracy: 0.643
# Epoch 12, CIFAR-10 Batch 3:  Loss: 0.75     Valid Accuracy: 0.669
# Epoch 12, CIFAR-10 Batch 4:  Loss: 0.75     Valid Accuracy: 0.672
# Epoch 12, CIFAR-10 Batch 5:  Loss: 0.809    Valid Accuracy: 0.66
# Epoch 13, CIFAR-10 Batch 1:  Loss: 0.846    Valid Accuracy: 0.664
# Epoch 13, CIFAR-10 Batch 2:  Loss: 0.788    Valid Accuracy: 0.676
# Epoch 13, CIFAR-10 Batch 3:  Loss: 0.734    Valid Accuracy: 0.674
# Epoch 13, CIFAR-10 Batch 4:  Loss: 0.727    Valid Accuracy: 0.676
# Epoch 13, CIFAR-10 Batch 5:  Loss: 0.772    Valid Accuracy: 0.68
# Epoch 14, CIFAR-10 Batch 1:  Loss: 0.817    Valid Accuracy: 0.673
# Epoch 14, CIFAR-10 Batch 2:  Loss: 0.754    Valid Accuracy: 0.674
# Epoch 14, CIFAR-10 Batch 3:  Loss: 0.747    Valid Accuracy: 0.669
# Epoch 14, CIFAR-10 Batch 4:  Loss: 0.705    Valid Accuracy: 0.685
# Epoch 14, CIFAR-10 Batch 5:  Loss: 0.733    Valid Accuracy: 0.681
# Epoch 15, CIFAR-10 Batch 1:  Loss: 0.791    Valid Accuracy: 0.685
# Epoch 15, CIFAR-10 Batch 2:  Loss: 0.748    Valid Accuracy: 0.673
# Epoch 15, CIFAR-10 Batch 3:  Loss: 0.682    Valid Accuracy: 0.686
# Epoch 15, CIFAR-10 Batch 4:  Loss: 0.687    Valid Accuracy: 0.691
# Epoch 15, CIFAR-10 Batch 5:  Loss: 0.731    Valid Accuracy: 0.695
# Epoch 16, CIFAR-10 Batch 1:  Loss: 0.748    Valid Accuracy: 0.682
# Epoch 16, CIFAR-10 Batch 2:  Loss: 0.706    Valid Accuracy: 0.69
# Epoch 16, CIFAR-10 Batch 3:  Loss: 0.676    Valid Accuracy: 0.689
# Epoch 16, CIFAR-10 Batch 4:  Loss: 0.663    Valid Accuracy: 0.701
# Epoch 16, CIFAR-10 Batch 5:  Loss: 0.68     Valid Accuracy: 0.7
# Epoch 17, CIFAR-10 Batch 1:  Loss: 0.717    Valid Accuracy: 0.695
# Epoch 17, CIFAR-10 Batch 2:  Loss: 0.669    Valid Accuracy: 0.698
# Epoch 17, CIFAR-10 Batch 3:  Loss: 0.633    Valid Accuracy: 0.696
# Epoch 17, CIFAR-10 Batch 4:  Loss: 0.633    Valid Accuracy: 0.706
# Epoch 17, CIFAR-10 Batch 5:  Loss: 0.661    Valid Accuracy: 0.708
# Epoch 18, CIFAR-10 Batch 1:  Loss: 0.691    Valid Accuracy: 0.701
# Epoch 18, CIFAR-10 Batch 2:  Loss: 0.648    Valid Accuracy: 0.708
# Epoch 18, CIFAR-10 Batch 3:  Loss: 0.629    Valid Accuracy: 0.691
# Epoch 18, CIFAR-10 Batch 4:  Loss: 0.641    Valid Accuracy: 0.708
# Epoch 18, CIFAR-10 Batch 5:  Loss: 0.642    Valid Accuracy: 0.721
# Epoch 19, CIFAR-10 Batch 1:  Loss: 0.675    Valid Accuracy: 0.711
# Epoch 19, CIFAR-10 Batch 2:  Loss: 0.629    Valid Accuracy: 0.714
# Epoch 19, CIFAR-10 Batch 3:  Loss: 0.582    Valid Accuracy: 0.71
# Epoch 19, CIFAR-10 Batch 4:  Loss: 0.597    Valid Accuracy: 0.717
# Epoch 19, CIFAR-10 Batch 5:  Loss: 0.629    Valid Accuracy: 0.712
# Epoch 20, CIFAR-10 Batch 1:  Loss: 0.665    Valid Accuracy: 0.709
# Epoch 20, CIFAR-10 Batch 2:  Loss: 0.611    Valid Accuracy: 0.715
# Epoch 20, CIFAR-10 Batch 3:  Loss: 0.57     Valid Accuracy: 0.721
# Epoch 20, CIFAR-10 Batch 4:  Loss: 0.582    Valid Accuracy: 0.714
# Epoch 20, CIFAR-10 Batch 5:  Loss: 0.633    Valid Accuracy: 0.717
# Epoch 21, CIFAR-10 Batch 1:  Loss: 0.611    Valid Accuracy: 0.72
# Epoch 21, CIFAR-10 Batch 2:  Loss: 0.587    Valid Accuracy: 0.727
# Epoch 21, CIFAR-10 Batch 3:  Loss: 0.552    Valid Accuracy: 0.713
# Epoch 21, CIFAR-10 Batch 4:  Loss: 0.547    Valid Accuracy: 0.729
# Epoch 21, CIFAR-10 Batch 5:  Loss: 0.589    Valid Accuracy: 0.722
# Epoch 22, CIFAR-10 Batch 1:  Loss: 0.595    Valid Accuracy: 0.727
# Epoch 22, CIFAR-10 Batch 2:  Loss: 0.581    Valid Accuracy: 0.719
# Epoch 22, CIFAR-10 Batch 3:  Loss: 0.552    Valid Accuracy: 0.712
# Epoch 22, CIFAR-10 Batch 4:  Loss: 0.536    Valid Accuracy: 0.732
# Epoch 22, CIFAR-10 Batch 5:  Loss: 0.561    Valid Accuracy: 0.729
# Epoch 23, CIFAR-10 Batch 1:  Loss: 0.593    Valid Accuracy: 0.73
# Epoch 23, CIFAR-10 Batch 2:  Loss: 0.549    Valid Accuracy: 0.738
# Epoch 23, CIFAR-10 Batch 3:  Loss: 0.522    Valid Accuracy: 0.728
# Epoch 23, CIFAR-10 Batch 4:  Loss: 0.54     Valid Accuracy: 0.724
# Epoch 23, CIFAR-10 Batch 5:  Loss: 0.558    Valid Accuracy: 0.726
# Epoch 24, CIFAR-10 Batch 1:  Loss: 0.592    Valid Accuracy: 0.722
# Epoch 24, CIFAR-10 Batch 2:  Loss: 0.605    Valid Accuracy: 0.723
# Epoch 24, CIFAR-10 Batch 3:  Loss: 0.49     Valid Accuracy: 0.731
# Epoch 24, CIFAR-10 Batch 4:  Loss: 0.51     Valid Accuracy: 0.736
# Epoch 24, CIFAR-10 Batch 5:  Loss: 0.537    Valid Accuracy: 0.726
# Epoch 25, CIFAR-10 Batch 1:  Loss: 0.553    Valid Accuracy: 0.737
# Epoch 25, CIFAR-10 Batch 2:  Loss: 0.509    Valid Accuracy: 0.741
# Epoch 25, CIFAR-10 Batch 3:  Loss: 0.472    Valid Accuracy: 0.744
# Epoch 25, CIFAR-10 Batch 4:  Loss: 0.503    Valid Accuracy: 0.73
# Epoch 25, CIFAR-10 Batch 5:  Loss: 0.522    Valid Accuracy: 0.732
# Epoch 26, CIFAR-10 Batch 1:  Loss: 0.517    Valid Accuracy: 0.74
# Epoch 26, CIFAR-10 Batch 2:  Loss: 0.486    Valid Accuracy: 0.738
# Epoch 26, CIFAR-10 Batch 3:  Loss: 0.471    Valid Accuracy: 0.739
# Epoch 26, CIFAR-10 Batch 4:  Loss: 0.467    Valid Accuracy: 0.742
# Epoch 26, CIFAR-10 Batch 5:  Loss: 0.479    Valid Accuracy: 0.738
# Epoch 27, CIFAR-10 Batch 1:  Loss: 0.522    Valid Accuracy: 0.742
# Epoch 27, CIFAR-10 Batch 2:  Loss: 0.471    Valid Accuracy: 0.747
# Epoch 27, CIFAR-10 Batch 3:  Loss: 0.458    Valid Accuracy: 0.755
# Epoch 27, CIFAR-10 Batch 4:  Loss: 0.463    Valid Accuracy: 0.737
# Epoch 27, CIFAR-10 Batch 5:  Loss: 0.493    Valid Accuracy: 0.735
# Epoch 28, CIFAR-10 Batch 1:  Loss: 0.511    Valid Accuracy: 0.727
# Epoch 28, CIFAR-10 Batch 2:  Loss: 0.47     Valid Accuracy: 0.744
# Epoch 28, CIFAR-10 Batch 3:  Loss: 0.451    Valid Accuracy: 0.739
# Epoch 28, CIFAR-10 Batch 4:  Loss: 0.447    Valid Accuracy: 0.747
# Epoch 28, CIFAR-10 Batch 5:  Loss: 0.478    Valid Accuracy: 0.745
# Epoch 29, CIFAR-10 Batch 1:  Loss: 0.508    Valid Accuracy: 0.729
# Epoch 29, CIFAR-10 Batch 2:  Loss: 0.481    Valid Accuracy: 0.732
# Epoch 29, CIFAR-10 Batch 3:  Loss: 0.448    Valid Accuracy: 0.744
# Epoch 29, CIFAR-10 Batch 4:  Loss: 0.444    Valid Accuracy: 0.746
# Epoch 29, CIFAR-10 Batch 5:  Loss: 0.442    Valid Accuracy: 0.75
# Epoch 30, CIFAR-10 Batch 1:  Loss: 0.465    Valid Accuracy: 0.748
# Epoch 30, CIFAR-10 Batch 2:  Loss: 0.44     Valid Accuracy: 0.75
# Epoch 30, CIFAR-10 Batch 3:  Loss: 0.412    Valid Accuracy: 0.751
# Epoch 30, CIFAR-10 Batch 4:  Loss: 0.426    Valid Accuracy: 0.754
# Epoch 30, CIFAR-10 Batch 5:  Loss: 0.409    Valid Accuracy: 0.753
# Epoch 31, CIFAR-10 Batch 1:  Loss: 0.471    Valid Accuracy: 0.739
# Epoch 31, CIFAR-10 Batch 2:  Loss: 0.435    Valid Accuracy: 0.756
# Epoch 31, CIFAR-10 Batch 3:  Loss: 0.413    Valid Accuracy: 0.747
# Epoch 31, CIFAR-10 Batch 4:  Loss: 0.42     Valid Accuracy: 0.75
# Epoch 31, CIFAR-10 Batch 5:  Loss: 0.427    Valid Accuracy: 0.751
# Epoch 32, CIFAR-10 Batch 1:  Loss: 0.443    Valid Accuracy: 0.752
# Epoch 32, CIFAR-10 Batch 2:  Loss: 0.46     Valid Accuracy: 0.746
# Epoch 32, CIFAR-10 Batch 3:  Loss: 0.387    Valid Accuracy: 0.75
# Epoch 32, CIFAR-10 Batch 4:  Loss: 0.392    Valid Accuracy: 0.755
# Epoch 32, CIFAR-10 Batch 5:  Loss: 0.444    Valid Accuracy: 0.742
# Epoch 33, CIFAR-10 Batch 1:  Loss: 0.426    Valid Accuracy: 0.753
# Epoch 33, CIFAR-10 Batch 2:  Loss: 0.394    Valid Accuracy: 0.752
# Epoch 33, CIFAR-10 Batch 3:  Loss: 0.392    Valid Accuracy: 0.754
# Epoch 33, CIFAR-10 Batch 4:  Loss: 0.397    Valid Accuracy: 0.748
# Epoch 33, CIFAR-10 Batch 5:  Loss: 0.39     Valid Accuracy: 0.751
# Epoch 34, CIFAR-10 Batch 1:  Loss: 0.439    Valid Accuracy: 0.738
# Epoch 34, CIFAR-10 Batch 2:  Loss: 0.394    Valid Accuracy: 0.755
# Epoch 34, CIFAR-10 Batch 3:  Loss: 0.397    Valid Accuracy: 0.741
# Epoch 34, CIFAR-10 Batch 4:  Loss: 0.382    Valid Accuracy: 0.753
# Epoch 34, CIFAR-10 Batch 5:  Loss: 0.365    Valid Accuracy: 0.755
# Epoch 35, CIFAR-10 Batch 1:  Loss: 0.403    Valid Accuracy: 0.759
# Epoch 35, CIFAR-10 Batch 2:  Loss: 0.391    Valid Accuracy: 0.759
# Epoch 35, CIFAR-10 Batch 3:  Loss: 0.38     Valid Accuracy: 0.756
# Epoch 35, CIFAR-10 Batch 4:  Loss: 0.39     Valid Accuracy: 0.75
# Epoch 35, CIFAR-10 Batch 5:  Loss: 0.37     Valid Accuracy: 0.751
# Epoch 36, CIFAR-10 Batch 1:  Loss: 0.404    Valid Accuracy: 0.754
# Epoch 36, CIFAR-10 Batch 2:  Loss: 0.361    Valid Accuracy: 0.761
# Epoch 36, CIFAR-10 Batch 3:  Loss: 0.359    Valid Accuracy: 0.764
# Epoch 36, CIFAR-10 Batch 4:  Loss: 0.368    Valid Accuracy: 0.755
# Epoch 36, CIFAR-10 Batch 5:  Loss: 0.355    Valid Accuracy: 0.758
# Epoch 37, CIFAR-10 Batch 1:  Loss: 0.374    Valid Accuracy: 0.758
# Epoch 37, CIFAR-10 Batch 2:  Loss: 0.356    Valid Accuracy: 0.76
# Epoch 37, CIFAR-10 Batch 3:  Loss: 0.353    Valid Accuracy: 0.751
# Epoch 37, CIFAR-10 Batch 4:  Loss: 0.357    Valid Accuracy: 0.762
# Epoch 37, CIFAR-10 Batch 5:  Loss: 0.333    Valid Accuracy: 0.766
# Epoch 38, CIFAR-10 Batch 1:  Loss: 0.37     Valid Accuracy: 0.749
# Epoch 38, CIFAR-10 Batch 2:  Loss: 0.34     Valid Accuracy: 0.768
# Epoch 38, CIFAR-10 Batch 3:  Loss: 0.34     Valid Accuracy: 0.761
# Epoch 38, CIFAR-10 Batch 4:  Loss: 0.357    Valid Accuracy: 0.757
# Epoch 38, CIFAR-10 Batch 5:  Loss: 0.338    Valid Accuracy: 0.763
# Epoch 39, CIFAR-10 Batch 1:  Loss: 0.365    Valid Accuracy: 0.756
# Epoch 39, CIFAR-10 Batch 2:  Loss: 0.345    Valid Accuracy: 0.764
# Epoch 39, CIFAR-10 Batch 3:  Loss: 0.338    Valid Accuracy: 0.769
# Epoch 39, CIFAR-10 Batch 4:  Loss: 0.346    Valid Accuracy: 0.763
# Epoch 39, CIFAR-10 Batch 5:  Loss: 0.332    Valid Accuracy: 0.768
# Epoch 40, CIFAR-10 Batch 1:  Loss: 0.367    Valid Accuracy: 0.755
# Epoch 40, CIFAR-10 Batch 2:  Loss: 0.341    Valid Accuracy: 0.767
# Epoch 40, CIFAR-10 Batch 3:  Loss: 0.328    Valid Accuracy: 0.764
# Epoch 40, CIFAR-10 Batch 4:  Loss: 0.341    Valid Accuracy: 0.761
# Epoch 40, CIFAR-10 Batch 5:  Loss: 0.308    Valid Accuracy: 0.77
# Epoch 41, CIFAR-10 Batch 1:  Loss: 0.368    Valid Accuracy: 0.754
# Epoch 41, CIFAR-10 Batch 2:  Loss: 0.336    Valid Accuracy: 0.755
# Epoch 41, CIFAR-10 Batch 3:  Loss: 0.301    Valid Accuracy: 0.77
# Epoch 41, CIFAR-10 Batch 4:  Loss: 0.333    Valid Accuracy: 0.756
# Epoch 41, CIFAR-10 Batch 5:  Loss: 0.331    Valid Accuracy: 0.753
# Epoch 42, CIFAR-10 Batch 1:  Loss: 0.337    Valid Accuracy: 0.762
# Epoch 42, CIFAR-10 Batch 2:  Loss: 0.339    Valid Accuracy: 0.762
# Epoch 42, CIFAR-10 Batch 3:  Loss: 0.333    Valid Accuracy: 0.755
# Epoch 42, CIFAR-10 Batch 4:  Loss: 0.321    Valid Accuracy: 0.764
# Epoch 42, CIFAR-10 Batch 5:  Loss: 0.294    Valid Accuracy: 0.766
# Epoch 43, CIFAR-10 Batch 1:  Loss: 0.335    Valid Accuracy: 0.77
# Epoch 43, CIFAR-10 Batch 2:  Loss: 0.313    Valid Accuracy: 0.768
# Epoch 43, CIFAR-10 Batch 3:  Loss: 0.3      Valid Accuracy: 0.767
# Epoch 43, CIFAR-10 Batch 4:  Loss: 0.293    Valid Accuracy: 0.764
# Epoch 43, CIFAR-10 Batch 5:  Loss: 0.3      Valid Accuracy: 0.76
# Epoch 44, CIFAR-10 Batch 1:  Loss: 0.33     Valid Accuracy: 0.755
# Epoch 44, CIFAR-10 Batch 2:  Loss: 0.304    Valid Accuracy: 0.767
# Epoch 44, CIFAR-10 Batch 3:  Loss: 0.292    Valid Accuracy: 0.767
# Epoch 44, CIFAR-10 Batch 4:  Loss: 0.287    Valid Accuracy: 0.764
# Epoch 44, CIFAR-10 Batch 5:  Loss: 0.31     Valid Accuracy: 0.756
# Epoch 45, CIFAR-10 Batch 1:  Loss: 0.313    Valid Accuracy: 0.764
# Epoch 45, CIFAR-10 Batch 2:  Loss: 0.313    Valid Accuracy: 0.765
# Epoch 45, CIFAR-10 Batch 3:  Loss: 0.287    Valid Accuracy: 0.773
# Epoch 45, CIFAR-10 Batch 4:  Loss: 0.293    Valid Accuracy: 0.765
# Epoch 45, CIFAR-10 Batch 5:  Loss: 0.271    Valid Accuracy: 0.775
# Epoch 46, CIFAR-10 Batch 1:  Loss: 0.293    Valid Accuracy: 0.767
# Epoch 46, CIFAR-10 Batch 2:  Loss: 0.293    Valid Accuracy: 0.769
# Epoch 46, CIFAR-10 Batch 3:  Loss: 0.291    Valid Accuracy: 0.769
# Epoch 46, CIFAR-10 Batch 4:  Loss: 0.29     Valid Accuracy: 0.77
# Epoch 46, CIFAR-10 Batch 5:  Loss: 0.273    Valid Accuracy: 0.763
# Epoch 47, CIFAR-10 Batch 1:  Loss: 0.294    Valid Accuracy: 0.772
# Epoch 47, CIFAR-10 Batch 2:  Loss: 0.304    Valid Accuracy: 0.759
# Epoch 47, CIFAR-10 Batch 3:  Loss: 0.277    Valid Accuracy: 0.771
# Epoch 47, CIFAR-10 Batch 4:  Loss: 0.29     Valid Accuracy: 0.764
# Epoch 47, CIFAR-10 Batch 5:  Loss: 0.286    Valid Accuracy: 0.761
# Epoch 48, CIFAR-10 Batch 1:  Loss: 0.296    Valid Accuracy: 0.772
# Epoch 48, CIFAR-10 Batch 2:  Loss: 0.295    Valid Accuracy: 0.765
# Epoch 48, CIFAR-10 Batch 3:  Loss: 0.262    Valid Accuracy: 0.775
# Epoch 48, CIFAR-10 Batch 4:  Loss: 0.293    Valid Accuracy: 0.764
# Epoch 48, CIFAR-10 Batch 5:  Loss: 0.297    Valid Accuracy: 0.763
# Epoch 49, CIFAR-10 Batch 1:  Loss: 0.301    Valid Accuracy: 0.768
# Epoch 49, CIFAR-10 Batch 2:  Loss: 0.285    Valid Accuracy: 0.77
# Epoch 49, CIFAR-10 Batch 3:  Loss: 0.279    Valid Accuracy: 0.763
# Epoch 49, CIFAR-10 Batch 4:  Loss: 0.276    Valid Accuracy: 0.771
# Epoch 49, CIFAR-10 Batch 5:  Loss: 0.251    Valid Accuracy: 0.77
# Epoch 50, CIFAR-10 Batch 1:  Loss: 0.315    Valid Accuracy: 0.762
# Epoch 50, CIFAR-10 Batch 2:  Loss: 0.289    Valid Accuracy: 0.769
# Epoch 50, CIFAR-10 Batch 3:  Loss: 0.259    Valid Accuracy: 0.77
# Epoch 50, CIFAR-10 Batch 4:  Loss: 0.3      Valid Accuracy: 0.761
# Epoch 50, CIFAR-10 Batch 5:  Loss: 0.256    Valid Accuracy: 0.77
# Epoch 51, CIFAR-10 Batch 1:  Loss: 0.281    Valid Accuracy: 0.78
# Epoch 51, CIFAR-10 Batch 2:  Loss: 0.257    Valid Accuracy: 0.78
# Epoch 51, CIFAR-10 Batch 3:  Loss: 0.257    Valid Accuracy: 0.764
# Epoch 51, CIFAR-10 Batch 4:  Loss: 0.267    Valid Accuracy: 0.769
# Epoch 51, CIFAR-10 Batch 5:  Loss: 0.238    Valid Accuracy: 0.777
# Epoch 52, CIFAR-10 Batch 1:  Loss: 0.266    Valid Accuracy: 0.785
# Epoch 52, CIFAR-10 Batch 2:  Loss: 0.253    Valid Accuracy: 0.774
# Epoch 52, CIFAR-10 Batch 3:  Loss: 0.25     Valid Accuracy: 0.771
# Epoch 52, CIFAR-10 Batch 4:  Loss: 0.256    Valid Accuracy: 0.77
# Epoch 52, CIFAR-10 Batch 5:  Loss: 0.223    Valid Accuracy: 0.774
# Epoch 53, CIFAR-10 Batch 1:  Loss: 0.266    Valid Accuracy: 0.782
# Epoch 53, CIFAR-10 Batch 2:  Loss: 0.253    Valid Accuracy: 0.772
# Epoch 53, CIFAR-10 Batch 3:  Loss: 0.242    Valid Accuracy: 0.768
# Epoch 53, CIFAR-10 Batch 4:  Loss: 0.251    Valid Accuracy: 0.77
# Epoch 53, CIFAR-10 Batch 5:  Loss: 0.233    Valid Accuracy: 0.77
# Epoch 54, CIFAR-10 Batch 1:  Loss: 0.261    Valid Accuracy: 0.774
# Epoch 54, CIFAR-10 Batch 2:  Loss: 0.247    Valid Accuracy: 0.774
# Epoch 54, CIFAR-10 Batch 3:  Loss: 0.228    Valid Accuracy: 0.775
# Epoch 54, CIFAR-10 Batch 4:  Loss: 0.266    Valid Accuracy: 0.762
# Epoch 54, CIFAR-10 Batch 5:  Loss: 0.237    Valid Accuracy: 0.774
# Epoch 55, CIFAR-10 Batch 1:  Loss: 0.266    Valid Accuracy: 0.778
# Epoch 55, CIFAR-10 Batch 2:  Loss: 0.25     Valid Accuracy: 0.773
# Epoch 55, CIFAR-10 Batch 3:  Loss: 0.241    Valid Accuracy: 0.765
# Epoch 55, CIFAR-10 Batch 4:  Loss: 0.261    Valid Accuracy: 0.757
# Epoch 55, CIFAR-10 Batch 5:  Loss: 0.238    Valid Accuracy: 0.776
# Epoch 56, CIFAR-10 Batch 1:  Loss: 0.254    Valid Accuracy: 0.778
# Epoch 56, CIFAR-10 Batch 2:  Loss: 0.241    Valid Accuracy: 0.771
# Epoch 56, CIFAR-10 Batch 3:  Loss: 0.219    Valid Accuracy: 0.768
# Epoch 56, CIFAR-10 Batch 4:  Loss: 0.238    Valid Accuracy: 0.775
# Epoch 56, CIFAR-10 Batch 5:  Loss: 0.216    Valid Accuracy: 0.782
# Epoch 57, CIFAR-10 Batch 1:  Loss: 0.236    Valid Accuracy: 0.779
# Epoch 57, CIFAR-10 Batch 2:  Loss: 0.217    Valid Accuracy: 0.781
# Epoch 57, CIFAR-10 Batch 3:  Loss: 0.23     Valid Accuracy: 0.773
# Epoch 57, CIFAR-10 Batch 4:  Loss: 0.222    Valid Accuracy: 0.781
# Epoch 57, CIFAR-10 Batch 5:  Loss: 0.212    Valid Accuracy: 0.778
# Epoch 58, CIFAR-10 Batch 1:  Loss: 0.231    Valid Accuracy: 0.781
# Epoch 58, CIFAR-10 Batch 2:  Loss: 0.236    Valid Accuracy: 0.779
# Epoch 58, CIFAR-10 Batch 3:  Loss: 0.216    Valid Accuracy: 0.769
# Epoch 58, CIFAR-10 Batch 4:  Loss: 0.212    Valid Accuracy: 0.772
# Epoch 58, CIFAR-10 Batch 5:  Loss: 0.214    Valid Accuracy: 0.767
# Epoch 59, CIFAR-10 Batch 1:  Loss: 0.235    Valid Accuracy: 0.78
# Epoch 59, CIFAR-10 Batch 2:  Loss: 0.225    Valid Accuracy: 0.779
# Epoch 59, CIFAR-10 Batch 3:  Loss: 0.227    Valid Accuracy: 0.757
# Epoch 59, CIFAR-10 Batch 4:  Loss: 0.213    Valid Accuracy: 0.776
# Epoch 59, CIFAR-10 Batch 5:  Loss: 0.207    Valid Accuracy: 0.773
# Epoch 60, CIFAR-10 Batch 1:  Loss: 0.237    Valid Accuracy: 0.777
# Epoch 60, CIFAR-10 Batch 2:  Loss: 0.224    Valid Accuracy: 0.781
# Epoch 60, CIFAR-10 Batch 3:  Loss: 0.229    Valid Accuracy: 0.76
# Epoch 60, CIFAR-10 Batch 4:  Loss: 0.239    Valid Accuracy: 0.767
# Epoch 60, CIFAR-10 Batch 5:  Loss: 0.214    Valid Accuracy: 0.77
# Epoch 61, CIFAR-10 Batch 1:  Loss: 0.242    Valid Accuracy: 0.768
# Epoch 61, CIFAR-10 Batch 2:  Loss: 0.227    Valid Accuracy: 0.775
# Epoch 61, CIFAR-10 Batch 3:  Loss: 0.203    Valid Accuracy: 0.775
# Epoch 61, CIFAR-10 Batch 4:  Loss: 0.225    Valid Accuracy: 0.773
# Epoch 61, CIFAR-10 Batch 5:  Loss: 0.218    Valid Accuracy: 0.765
# Epoch 62, CIFAR-10 Batch 1:  Loss: 0.246    Valid Accuracy: 0.772
# Epoch 62, CIFAR-10 Batch 2:  Loss: 0.209    Valid Accuracy: 0.785
# Epoch 62, CIFAR-10 Batch 3:  Loss: 0.205    Valid Accuracy: 0.772
# Epoch 62, CIFAR-10 Batch 4:  Loss: 0.221    Valid Accuracy: 0.772
# Epoch 62, CIFAR-10 Batch 5:  Loss: 0.211    Valid Accuracy: 0.771
# Epoch 63, CIFAR-10 Batch 1:  Loss: 0.214    Valid Accuracy: 0.776
# Epoch 63, CIFAR-10 Batch 2:  Loss: 0.195    Valid Accuracy: 0.784
# Epoch 63, CIFAR-10 Batch 3:  Loss: 0.192    Valid Accuracy: 0.774
# Epoch 63, CIFAR-10 Batch 4:  Loss: 0.236    Valid Accuracy: 0.772
# Epoch 63, CIFAR-10 Batch 5:  Loss: 0.206    Valid Accuracy: 0.775
# Epoch 64, CIFAR-10 Batch 1:  Loss: 0.218    Valid Accuracy: 0.779
# Epoch 64, CIFAR-10 Batch 2:  Loss: 0.208    Valid Accuracy: 0.775
# Epoch 64, CIFAR-10 Batch 3:  Loss: 0.19     Valid Accuracy: 0.775
# Epoch 64, CIFAR-10 Batch 4:  Loss: 0.233    Valid Accuracy: 0.769
# Epoch 64, CIFAR-10 Batch 5:  Loss: 0.212    Valid Accuracy: 0.776
# Epoch 65, CIFAR-10 Batch 1:  Loss: 0.202    Valid Accuracy: 0.778
# Epoch 65, CIFAR-10 Batch 2:  Loss: 0.193    Valid Accuracy: 0.776
# Epoch 65, CIFAR-10 Batch 3:  Loss: 0.19     Valid Accuracy: 0.779
# Epoch 65, CIFAR-10 Batch 4:  Loss: 0.217    Valid Accuracy: 0.771
# Epoch 65, CIFAR-10 Batch 5:  Loss: 0.182    Valid Accuracy: 0.777
# Epoch 66, CIFAR-10 Batch 1:  Loss: 0.199    Valid Accuracy: 0.781
# Epoch 66, CIFAR-10 Batch 2:  Loss: 0.18     Valid Accuracy: 0.783
# Epoch 66, CIFAR-10 Batch 3:  Loss: 0.173    Valid Accuracy: 0.78
# Epoch 66, CIFAR-10 Batch 4:  Loss: 0.218    Valid Accuracy: 0.773
# Epoch 66, CIFAR-10 Batch 5:  Loss: 0.183    Valid Accuracy: 0.774
# Epoch 67, CIFAR-10 Batch 1:  Loss: 0.196    Valid Accuracy: 0.782
# Epoch 67, CIFAR-10 Batch 2:  Loss: 0.204    Valid Accuracy: 0.78
# Epoch 67, CIFAR-10 Batch 3:  Loss: 0.164    Valid Accuracy: 0.783
# Epoch 67, CIFAR-10 Batch 4:  Loss: 0.207    Valid Accuracy: 0.766
# Epoch 67, CIFAR-10 Batch 5:  Loss: 0.176    Valid Accuracy: 0.778
# Epoch 68, CIFAR-10 Batch 1:  Loss: 0.192    Valid Accuracy: 0.785
# Epoch 68, CIFAR-10 Batch 2:  Loss: 0.191    Valid Accuracy: 0.783
# Epoch 68, CIFAR-10 Batch 3:  Loss: 0.171    Valid Accuracy: 0.778
# Epoch 68, CIFAR-10 Batch 4:  Loss: 0.175    Valid Accuracy: 0.78
# Epoch 68, CIFAR-10 Batch 5:  Loss: 0.194    Valid Accuracy: 0.761
# Epoch 69, CIFAR-10 Batch 1:  Loss: 0.194    Valid Accuracy: 0.777
# Epoch 69, CIFAR-10 Batch 2:  Loss: 0.168    Valid Accuracy: 0.785
# Epoch 69, CIFAR-10 Batch 3:  Loss: 0.164    Valid Accuracy: 0.783
# Epoch 69, CIFAR-10 Batch 4:  Loss: 0.195    Valid Accuracy: 0.765
# Epoch 69, CIFAR-10 Batch 5:  Loss: 0.175    Valid Accuracy: 0.775
# Epoch 70, CIFAR-10 Batch 1:  Loss: 0.196    Valid Accuracy: 0.779
# Epoch 70, CIFAR-10 Batch 2:  Loss: 0.18     Valid Accuracy: 0.777
# Epoch 70, CIFAR-10 Batch 3:  Loss: 0.157    Valid Accuracy: 0.779
# Epoch 70, CIFAR-10 Batch 4:  Loss: 0.233    Valid Accuracy: 0.759
# Epoch 70, CIFAR-10 Batch 5:  Loss: 0.166    Valid Accuracy: 0.783
# Epoch 71, CIFAR-10 Batch 1:  Loss: 0.183    Valid Accuracy: 0.789
# Epoch 71, CIFAR-10 Batch 2:  Loss: 0.19     Valid Accuracy: 0.776
# Epoch 71, CIFAR-10 Batch 3:  Loss: 0.162    Valid Accuracy: 0.772
# Epoch 71, CIFAR-10 Batch 4:  Loss: 0.191    Valid Accuracy: 0.773
# Epoch 71, CIFAR-10 Batch 5:  Loss: 0.158    Valid Accuracy: 0.779
# Epoch 72, CIFAR-10 Batch 1:  Loss: 0.18     Valid Accuracy: 0.791
# Epoch 72, CIFAR-10 Batch 2:  Loss: 0.175    Valid Accuracy: 0.777
# Epoch 72, CIFAR-10 Batch 3:  Loss: 0.172    Valid Accuracy: 0.761
# Epoch 72, CIFAR-10 Batch 4:  Loss: 0.179    Valid Accuracy: 0.782
# Epoch 72, CIFAR-10 Batch 5:  Loss: 0.156    Valid Accuracy: 0.776
# Epoch 73, CIFAR-10 Batch 1:  Loss: 0.186    Valid Accuracy: 0.79
# Epoch 73, CIFAR-10 Batch 2:  Loss: 0.16     Valid Accuracy: 0.788
# Epoch 73, CIFAR-10 Batch 3:  Loss: 0.174    Valid Accuracy: 0.767
# Epoch 73, CIFAR-10 Batch 4:  Loss: 0.194    Valid Accuracy: 0.769
# Epoch 73, CIFAR-10 Batch 5:  Loss: 0.156    Valid Accuracy: 0.779
# Epoch 74, CIFAR-10 Batch 1:  Loss: 0.183    Valid Accuracy: 0.79
# Epoch 74, CIFAR-10 Batch 2:  Loss: 0.184    Valid Accuracy: 0.78
# Epoch 74, CIFAR-10 Batch 3:  Loss: 0.148    Valid Accuracy: 0.779
# Epoch 74, CIFAR-10 Batch 4:  Loss: 0.184    Valid Accuracy: 0.766
# Epoch 74, CIFAR-10 Batch 5:  Loss: 0.161    Valid Accuracy: 0.776
# Epoch 75, CIFAR-10 Batch 1:  Loss: 0.184    Valid Accuracy: 0.788
# Epoch 75, CIFAR-10 Batch 2:  Loss: 0.171    Valid Accuracy: 0.78
# Epoch 75, CIFAR-10 Batch 3:  Loss: 0.14     Valid Accuracy: 0.783
# Epoch 75, CIFAR-10 Batch 4:  Loss: 0.181    Valid Accuracy: 0.77
# Epoch 75, CIFAR-10 Batch 5:  Loss: 0.154    Valid Accuracy: 0.773

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# INFO:tensorflow:Restoring parameters from ./image_classification
# Testing Accuracy: 0.7641429215669632

# %% [markdown]
# ## Why 50-70% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 70%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
